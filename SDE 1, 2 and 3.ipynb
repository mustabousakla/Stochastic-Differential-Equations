# %%
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

a = 2
g = np.sqrt(0.05) #sqrt(D)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
for i in range(10):
    x=1
    t=0
    traj=[]
    time=[]
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj.append(x)
        time.append(t)
    plt.plot(time,traj)
   
time2=np.linspace(0,5,100)
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2, label=r'$e^{-2t}$')  
plt.xlim([0,5])
plt.ylabel('x(t)')
plt.xlabel('t')
plt.legend()
plt.show()

# %%
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time


a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
for i in range(10):
    x=1
    t=0
    traj[i][]=[]
    time=[]
    
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j].append(x)
        time.append(t)
    print(traj)
     
    
    
    
    

time2=np.linspace(0,5,100)
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.xlim([0,5])
plt.ylabel('x(t)')
plt.xlabel('t')
plt.show()
# Out:
#   File "<ipython-input-115-26e4d155512a>", line 26
#     traj[i][]=[]
#             ^
# SyntaxError: invalid syntax

# %%
#MATRIX está bien

import numpy as np
import math
import random 
from matplotlib import pyplot as plt
import time


a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
traj=np.zeros((10,nsteps))
for i in range(10):
    x=1
    t=0
    time=np.zeros(nsteps)
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        time[j]=t
    plt.plot(time,traj[i])
   
time2=np.linspace(0,5,100)
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.xlim([0,5])
plt.ylabel('x(t)')
plt.xlabel('t')
plt.show()

firstmom=np.zeros(nsteps)
for j in range(nsteps):
    for i in range(10):
        firstmom[j]=np.mean(traj[i][j])
        
        
plt.plot(time,firstmom)    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.show()

# %%
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

time_start = time.clock()

a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
traj=np.zeros((100,nsteps))
firstmom=np.zeros(nsteps)
time2=np.zeros(nsteps)
for i in range(100):
    x=1
    t=0
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        time2[j]=t
        for i in range(100):
            firstmom[j]=np.mean(traj[i][j])

        
plt.plot(time2,firstmom)    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.show()

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 119.149913

# %%
#una media bien hecha!!!!
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

time_start = time.clock()

a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
traj=np.zeros((100,nsteps))
firstmom=np.zeros(nsteps)

time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*20
    
suma=np.zeros(nsteps)
for i in range(100):
    x=1
    t=0
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        
        
for j in range(nsteps):
    for i in range(100):
        suma[j]+=traj[i][j]

        
plt.plot(time2,suma/100)    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.show()

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 9.9437854

# %%
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

time_start = time.clock()

a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 250
x = 1
t = 0

def q(x):
    return -a*x


# MILSHTEIN ALGORITHM
traj=np.zeros((100,nsteps))
firstmom=np.zeros(nsteps)

time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*20
    
suma=np.zeros(nsteps)
for i in range(100):
    x=1
    t=0
    for j in range(nsteps):
        for k in range(20):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        for l in range(100):
            suma[j]+=traj[i][j]
            


        
plt.plot(time2,suma/100)    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.show()

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 15.1904075

# %%
#todas las medias

time_start = time.clock()
a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 100
x = 1
t = 0

def q(x):
    return -a*x

time2=np.zeros(nsteps)
for k in range(1,3):
    firstmom=np.zeros(nsteps)
    num=10**k
    traj=np.zeros((num,nsteps))
    for i in range(num):
        x=1
        t=0
        for j in range(nsteps):
            for k in range(50):
                uh=h_sqrt*np.random.normal()
                x = x + h * q(x) + g * uh
                t=t+h
            traj[i][j]=x
            time2[j]=t
            for l in range(num):
                firstmom[j]=np.mean(traj[l][j])
            
    plt.plot(time2,firstmom, label=num)
    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2)  
plt.xlim([0,5])
plt.ylabel('<x(t)>')
plt.xlabel('t')
plt.legend()
plt.show()      
   

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-69742f5bf60e> in <module>()
#      29             time2[j]=t
#      30             for l in range(num):
# ---> 31                 firstmom[j]=np.mean(traj[l][j])
#      32
#      33     plt.plot(time2,firstmom, label=num)
#
# C:\Users\musta\Anaconda2\lib\site-packages\numpy\core\fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2952             pass
#    2953         else:
# -> 2954             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
#
# C:\Users\musta\Anaconda2\lib\site-packages\numpy\core\_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      55
#      56     is_float16_result = False
# ---> 57     rcount = _count_reduce_items(arr, axis)
#      58     # Make this warning show up first
#      59     if rcount == 0:
#
# C:\Users\musta\Anaconda2\lib\site-packages\numpy\core\_methods.pyc in _count_reduce_items(arr, axis)
#      44     if axis is None:
#      45         axis = tuple(range(arr.ndim))
# ---> 46     if not isinstance(axis, tuple):
#      47         axis = (axis,)
#      48     items = 1
#
# KeyboardInterrupt:

# %%
#por fin primer momento

time_start = time.clock()
a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 100
x = 1
t = 0

def q(x):
    return -a*x
t=0
time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*50
    

for k in range(1,4):
    suma=np.zeros(nsteps)
    num=10**k
    traj=np.zeros((num,nsteps))
    for i in range(num):
        x=1
        t=0
        for j in range(nsteps):
            for k in range(50):
                uh=h_sqrt*np.random.normal()
                x = x + h * q(x) + g * uh
                t=t+h
            traj[i][j]=x
            
    for l in range(nsteps):
        for m in range(num):
            suma[l]+=traj[m][l]

        
    plt.plot(time2,suma/num, label=num)        
    
plt.plot(time2,np.exp(-a*time2), 'k--', linewidth=2, label=r'$e^{-2t}$')  
plt.xlim([0,5])
plt.ylabel('<x(t)>')
plt.xlabel('t')
plt.legend()
plt.show()      
   

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 106.3495577

# %%
#second moment
time_start = time.clock()
a = 2
g = np.sqrt(0.05)
h =0.001
h_sqrt=np.sqrt(h)
nsteps = 100
x = 1
t = 0

def q(x):
    return -a*x
t=0
time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*50
    

for k in range(1,4):
    suma=np.zeros(nsteps)
    num=10**k
    traj=np.zeros((num,nsteps))
    for i in range(num):
        x=1
        t=0
        for j in range(nsteps):
            for k in range(50):
                uh=h_sqrt*np.random.normal()
                x = x + h * q(x) + g * uh
                t=t+h
            traj[i][j]=x
            
    for l in range(nsteps):
        for m in range(num):
            suma[l]+=traj[m][l]**2

        
    plt.plot(time2,suma/num, label=num)        
    
plt.plot(time2,np.exp(-2*a*time2), 'k--', linewidth=2, label=r'$e^{-4t}$')  
plt.xlim([0,5])
plt.ylabel(r'$<x(t)^2>$', fontsize=15)
plt.xlabel(r'$t$', fontsize=15)
plt.legend()
plt.show()      
   

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 106.6864308

# %%
#influence of time step
time_start=time.clock()

a = 2
g = np.sqrt(0.05)
h = [0.0001,0.001,0.01,0.1,0.5]
h_sqrt=np.sqrt(h)
nsteps = [10000,1000,100,10,2]
x = 1
t = 0
numtraj=1000

def q(x):
    return -a*x


for k in range(5):
    suma=np.zeros(nsteps[k])
    suma2=np.zeros(nsteps[k])
    traj=np.zeros((numtraj,nsteps[k]))
    time2=np.zeros(nsteps[k])
    for i in range(numtraj):
        x=1
        t=0
        for j in range(nsteps[k]):
            uh=h_sqrt[k]*np.random.normal()
            x = x + h[k] * q(x) + g * uh
            t=t+h[k]
            traj[i][j]=x
            time2[j]=t
            
    for l in range(nsteps[k]):
        for m in range(numtraj):
            suma[l]+=traj[m][l]

        
    plt.plot(np.log(h[k]),suma[nsteps[k]-1]/numtraj,'o', markersize=5, label=h[k])
    

plt.ylim([-0.01,0.16])
plt.ylabel(r'$<x(1)>$', fontsize=15)
plt.xlabel(r'$log(h)$', fontsize=15)
plt.legend(numpoints=1, fontsize=8)

plt.show()    
   

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 323.0983319

# %%
#influence of time step
time_start = time.clock()
a = 2
g = np.sqrt(0.05)
h = [0.0001,0.001,0.01,0.1,0.5]
h_sqrt=np.sqrt(h)
nsteps = [10000,1000,100,10,2]
x = 1
t = 0
numtraj=1000

def q(x):
    return -a*x


for k in range(5):
    suma=np.zeros(nsteps[k])
    suma2=np.zeros(nsteps[k])
    traj=np.zeros((numtraj,nsteps[k]))
    time2=np.zeros(nsteps[k])
    for i in range(numtraj):
        x=1
        t=0
        for j in range(nsteps[k]):
            uh=h_sqrt[k]*np.random.normal()
            x = x + h[k] * q(x) + g * uh
            t=t+h[k]
            traj[i][j]=x
            time2[j]=t
            
    for l in range(nsteps[k]):
        for m in range(numtraj):
            suma2[l]+=traj[m][l]**2

        
    plt.plot(np.log(h[k]),suma2[nsteps[k]-1]/numtraj,'o', markersize=5, label=h[k])
    

plt.ylabel(r'$<x(1)^2>$', fontsize=15)
plt.xlabel(r'$log(h)$', fontsize=15)
plt.legend(numpoints=1, fontsize=8)
plt.show()    
   

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 309.8783427

# %%
#correlation function and corr time

import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

time_start = time.clock()

a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 1000
x = 1
t = 0
numtraj=1000
time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*5


def q(x):
    return -a*x



traj=np.zeros((numtraj,nsteps))
tstep= [100, 200, 400, 1000] #correspond to times 0.5,1,2,5
s=np.linspace(0,5,250)
              
for i in range(numtraj):
    x=1
    t=0
    for j in range(nsteps):
        for k in range(5):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        
    
for l in range(4):
    Corr=np.zeros(250)
    for m in range(250):
        suma=0
        for p in range(numtraj):
            if tstep[l]+4*m <nsteps:
                suma+=traj[p][tstep[l]-1]*traj[p][tstep[l]+4*m] #increase of 0.02 in s is increase of 4 steps
        Corr[m]=suma/numtraj
    plt.plot(s,Corr, label=tstep[l]*0.005)
    plt.plot(Corr,s,label=tstep[l]*0.005)
    print(Corr[0]*1/np.e)



plt.ylabel('C(s,t)')
plt.xlabel('s')
plt.legend()
plt.show()

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 0.05390398685453334
# 0.011873019005037797
# 0.004770222728452707
# 0.0
# 107.1071737

# %%
import numpy as np
import math
import itertools
import random 
from matplotlib import pyplot as plt
import scipy
import time

time_start = time.clock()

a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 1000
x = 1
t = 0
numtraj=1000
time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*5


def q(x):
    return -a*x



traj=np.zeros((numtraj,nsteps))
tstep= [100, 200, 400, 1000] #correspond to times 0.5,1,2,5
s=np.linspace(0,5,250)
              
for i in range(numtraj):
    x=1
    t=0
    for j in range(nsteps):
        for k in range(5):
            uh=h_sqrt*np.random.normal()
            x = x + h * q(x) + g * uh
            t=t+h
        traj[i][j]=x
        
    
for l in range(4):
    Corr=np.zeros(250)
    for m in range(250):
        suma=0
        for p in range(numtraj):
            if tstep[l]+4*m <nsteps:
                suma+=traj[p][tstep[l]-1]*traj[p][tstep[l]+4*m] #increase of 0.02 in s is increase of 4 steps
        Corr[m]=suma/numtraj
    plt.plot(s,Corr, label=tstep[l]*0.005)



plt.ylabel('C(s,t)')
plt.xlabel('s')
plt.legend()
plt.show()

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 108.354958

# %%
a = 2
g = np.sqrt(0.05)
h = 0.001
h_sqrt=np.sqrt(h)
nsteps = 50000
x = 1
t = 0
traj=np.zeros(nsteps)

time2=np.zeros(nsteps)
for i in range(nsteps):
    time2[i]=h*i*20


def q(x):
    return -a*x

s=np.linspace(0,5,250)

for i in range(nsteps):
    for k in range(20):
        uh=h_sqrt*np.random.normal()
        x = x + h * q(x) + g * uh
        t=t+h
    traj[i]=x
    

for m in range(250):
    suma=0
    for p in range(nsteps):
        if p+m <nsteps:
            suma+=traj[p]*traj[p+m] #increase of 0.02 in s is increase of 1 stored step
    Corr[m]=np.float(suma)/nsteps
    
plt.plot(s,Corr)
plt.ylabel(r'$\tilde{C}(s,t)$', fontsize=15)
plt.xlabel(r'$s$', fontsize=15)
plt.show()
